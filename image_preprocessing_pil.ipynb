# %%
#image preprocessing

# %%
# pillow : pip install pillow and opencv: pip install opencv-python

# %%
# !pip install pillow

# %%
# !pip install opencv-python

# %%
from PIL import Image

# %%
image=Image.open("nike shoe2.png")

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=261x128>

# %%
image.show()

# %%
image.size   #size of image
# Out:
# (261, 128)

# %%
image.format
# Out:
# 'PNG'

# %%
image.mode
# Mode	Description
# 1	1-bit pixels, black and white
# L	8-bit pixels, Grayscale
# P	8-bit pixels, mapped to any other mode using a color palette
# RGB	3×8-bit pixels, true color
# RGBA	4×8-bit pixels, true color with transparency mask
# Out:
# 'RGBA'

# %%
image.rotate(90,expand=1)
# Out:
# <PIL.Image.Image image mode=RGBA size=128x261>

# %%
image.rotate(45,expand=1)
# Out:
# <PIL.Image.Image image mode=RGBA size=277x276>

# %%
image.rotate(180,expand=1)
# Out:
# <PIL.Image.Image image mode=RGBA size=261x128>

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=261x128>

# %%
w,h=image.size

# %%
w
# Out:
# 261

# %%
h
# Out:
# 128

# %%
new_size=(200,200)

# %%
image.resize(new_size)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200>

# %%
# Setting the points for cropped image
left = 4
top = h / 5
right = 154
bottom = 3 * h / 5

# %%
image.crop((left,top,right,bottom))
# Out:
# <PIL.Image.Image image mode=RGBA size=150x51>

# %%
new_mode="L"  #gray scale

# %%
image.mode
# Out:
# 'RGBA'

# %%
image2=image.convert("L")

# %%
image2.mode
# Out:
# 'L'

# %%
image=Image.open("nike shoe2.png")

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=261x128>

# %%
image.split()
# Out:
# (<PIL.Image.Image image mode=L size=261x128>,
#  <PIL.Image.Image image mode=L size=261x128>,
#  <PIL.Image.Image image mode=L size=261x128>,
#  <PIL.Image.Image image mode=L size=261x128>)

# %%
#check dimension of image

# %%
import numpy as np

# %%
img=Image.open("nike shoe2.png")

# %%
array=np.array(img)

# %%
dim=len(array.shape)

# %%
dim
# Out:
# 3
